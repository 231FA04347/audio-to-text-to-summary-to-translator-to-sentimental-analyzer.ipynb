# %%
# !pip install SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 34.2 MB/s eta 0:00:00
# ...

# %%
import speech_recognition as sr

# %%
model=sr.Recognizer()

# %%
# !pip install pydub

# %%
mp3_file=r'/content/waste.mp3'
from pydub import AudioSegment
from pydub.playback import play
# Use from_file instead of from_mp4 to load the file
audio=AudioSegment.from_file(mp3_file)
audio.export('audio.wav',format='wav')
# Out:
# <_io.BufferedRandom name='audio.wav'>

# %%
audio_file=r'/content/audio.wav'
with sr.AudioFile(audio_file) as source:
  audio_data=model.record(source)
  text=model.recognize_google(audio_data)
text
# Out:
# 'hello this is Sweetwater from batch agency box'

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
summary=pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %%
texts=input('Enter text: ')
# Out:
# Enter text: Main Idea The Telugu Cinema Industry, popularly known as Tollywood, is one of the largest and most influential film industries in India.  It produces films mainly in the Telugu language, spoken widely in Andhra Pradesh and Telangana.  Origins and Early History   - The first Telugu film, "Bhakta Prahlada" (1931), was a talkie directed by H.M. Reddy.   - Early films focused on mythology and social messages.  Golden Era (1950s–1970s)   - Legendary actors like N.T. Rama Rao (NTR) and Akkineni Nageswara Rao (ANR) rose to fame.   - Directors like K. Vishwanath brought depth to Telugu cinema through art and culture.  Modern Development (1980s–2000s)   - Introduction of commercial cinema with action, drama, and mass appeal.   - Stars like Chiranjeevi, Balakrishna, and Venkatesh dominated the screen.   - Technical aspects improved, and Telugu films gained national recognition.  Contemporary Tollywood (2010s–present)   - Rise of Pan-India Films like Baahubali, RRR, and Pushpa.   - 
# ...

# %%
summ=summary(texts)
summ
# Out:
# [{'summary_text': ' The Telugu Cinema Industry is one of the largest and most influential film industries in India . It produces films mainly in the Telugu language, spoken widely in Andhra Pradesh and Telangana . The first Telugu film, "Bhakta Prahlada" (1931), was a talkie directed by H.M. Reddy .'}]

# %%
q_a = pipeline('question-answering')

context = """
 Machine learning teach a computer how to perform a task without explicitly programming it to perform set task instead feed data into an algorithm to gradually improve outcomes . The term was coined in 1959 by Arthur Samuel at IBM who is developing artificial intelligence that could play checkers half a century later . Predictive models are embedded in many of the products we use every day
"""
while True:
    question = input("Enter your question: ")
    if question.lower() == 'quit':
        break

    result_txt = q_a({
        'question': question,
        'context': context
    })

    print("Answer:", result_txt['answer'])
    print("-" * 20) # Separator for clarity

print("Exiting the question-answering session.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# ...

# %%
from transformers import pipeline

traslator = pipeline('translation_en_to_fe', model='Helsinki-NLP/opus-mt-de-en')

in_text = input('Enter text: ')

r = traslator(in_text)
r

# %%
analyzer=pipeline('sentiment-analysis')

# %%
text_input=input("Enter some text: ")

# %%
result=analyzer(text_input)
result

# %%
visual_q_a=pipeline('vqa')
# Out:
# No model was supplied, defaulted to dandelin/vilt-b32-finetuned-vqa and revision d0a1f6a (https://huggingface.co/dandelin/vilt-b32-finetuned-vqa).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/136k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/470M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/470M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# ...

# %% [markdown]
# **image generator**

# %%
# !pip install diffusers
from transformers import pipeline
# import touch # Removed the incorrect import statement
from diffusers import DiffusionPipeline
generator = DiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")
generator.to("cuda")
# Out:
# ...
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
Prompt= "A giant, floating pizza slice soaring through a cloud-filled sky, with tiny dinosaurs parachuting off it. The pizza has glowing pepperoni that twinkle like stars, and the dinosaurs are wearing tiny astronaut helmets. Below, a city made of ice cream cones is slowly melting under the bright sun. A rainbow is arching over it, but the colors are all mismatched like a painter’s palette gone wild."

# %%
imq=generator(Prompt).images[0]
imq
# Out:
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['a painter ’ s palette gone wild .']
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
